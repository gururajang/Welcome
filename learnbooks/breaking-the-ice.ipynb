# %%
#@title 
# %%html
<marquee style='width: 100%; color: #00a7f4;font-size:30px;'><b>Welcome to Mentorskool!</b></marquee>
# Out:
# <marquee style='width: 100%; color: #00a7f4;font-size:30px;'><b>Welcome to Mentorskool!</b></marquee>

# %% [markdown]
# ### **Mentorclass - Kick Off**
# -----
# We'll be learning about below topics in this class :
#
# * Getting an overview of an end-to-end **Data Science Project**
# * Understanding the skill sets required to grow as a **Full Stack Data Scientist**
# * Looking at a sample portfolio of a  **Professional Data Scientist** look like?
# * Making sense of the exciting field of **Data Analytics**
# * Time for **MentorQuizz!**

# %% [markdown]
# ### **01. Looking at an end-to-end Data Science Project**
# --------------------------------
# *Click on the play button to start!*

# %%
#@title
# %%html
<iframe src="https://docs.google.com/presentation/d/e/2PACX-1vQicoSq0ahKmXBepvJlJ98UA15iB7HsL8yb-SGRy-DkcGeDVcNmVlQZNV3uHVUznrlxcNu3_cLlhmdC/embed?start=false&loop=false&delayms=3000" 
frameborder="0" 
width="800" 
height="500" 
allowfullscreen="true" 
mozallowfullscreen="true" 
webkitallowfullscreen="true"></iframe>
# Out:
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vQicoSq0ahKmXBepvJlJ98UA15iB7HsL8yb-SGRy-DkcGeDVcNmVlQZNV3uHVUznrlxcNu3_cLlhmdC/embed?start=false&loop=false&delayms=3000"
# frameborder="0"
# width="800"
# height="500"
# allowfullscreen="true"
# mozallowfullscreen="true"
# webkitallowfullscreen="true"></iframe>

# %% [markdown]
# ### **02. Skill sets of a Full Stack Data Scientist**
# ----------------------------
# *Click on the play button to start!*
# * Please note that the skill-sets mentioned are to be acquired over time starting from very basic **data analysis skills** and advancing to as high level skills as **Big Data** or **Deep Learning**

# %%
#@title
from IPython.display import HTML
HTML(
"""
<iframe src="https://docs.google.com/presentation/d/e/2PACX-1vSDgkJHt-lO51u38qdpnLSbyAB0pQtqCjxUkcChKObf2nXCVOQNne1aESWiu5zkLRpDYOPQjGsnhp1T/embed?start=false&loop=false&delayms=3000" 
frameborder="0" 
width="800" 
height="500" 
allowfullscreen="true" 
mozallowfullscreen="true" 
webkitallowfullscreen="true"></iframe>
"""
)
# Out:
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vSDgkJHt-lO51u38qdpnLSbyAB0pQtqCjxUkcChKObf2nXCVOQNne1aESWiu5zkLRpDYOPQjGsnhp1T/embed?start=false&loop=false&delayms=3000"
# frameborder="0"
# width="800"
# height="500"
# allowfullscreen="true"
# mozallowfullscreen="true"
# webkitallowfullscreen="true"></iframe>

# %% [markdown]
# ### **03. An Ideal portfolio of your skills**
# ----------------------------
# *Click on the play button to start!*
# * Completely developed using **GitHub Pages** and **markdowns**
# * All your **best work** goes into the **Projects** section exposed to the outside world as a beautifully formatted web page

# %%
#@title 
from IPython.display import HTML
HTML(
"""
<iframe src="https://jeromelachaud.com/freelancer-theme/" 
frameborder="0" 
width="1000" 
height="500" 
allowfullscreen="true" 
mozallowfullscreen="true" 
webkitallowfullscreen="true"></iframe>
"""
)
# Out:
# <iframe src="https://jeromelachaud.com/freelancer-theme/"
# frameborder="0"
# width="1000"
# height="500"
# allowfullscreen="true"
# mozallowfullscreen="true"
# webkitallowfullscreen="true"></iframe>

# %% [markdown]
# ### **04. Making sense of Data Analytics/Science**
# ----------------------------
# * This is a 4 part video series (Duration : **45 min**)
# * Start with the below video and sequentially watch them till part 4
# * Take a **quick quiz** to test your understanding and get your scores instantly!

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('MzMiCJEaHXU',width=900, height=500)

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('NroS1rh-Ugw',width=900, height=500)

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('-cTAxFTpwjI',width=900, height=500)

# %%
#@title
from IPython.display import YouTubeVideo
YouTubeVideo('JWGT-rcuGyg',width=900, height=500)

# %% [markdown]
# ### **05. Time for a quick quiz!**
# ----------------------------
# * Take the quiz [**here**]() and assess your learning
# * Ideal completion time : **5 minutes**

# %% [markdown]
# <font size="5" color="#2c5bc7"><b>That's all for now folks!</font><br>
# **Hope you enjoyed this learnbook. Will be back with a new one pretty soon...**
